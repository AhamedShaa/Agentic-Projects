# %%
# !pip install langchain
# !pip install unstructured
# !pip install openai
# !pip install Cython
# !pip install tiktoken

# %%
# !pip install --upgrade langchain-astradb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.5/333.5 kB 24.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 75.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 32.6 MB/s eta 0:00:00
# ...

# %%
# !pip install "unstructured[pdf]"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 38.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 40.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 76.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 52.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.9/527.9 kB 37.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 144.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 48.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 117.1 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain langchain-openai datasets pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 5.1 MB/s eta 0:00:00
# ...

# %%
# !pip install pdf2image

# %%
# !pip install pdfminer.six

# %%
# !pip install unstructured[pdf]

# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 7.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
folder_path = './docs/'

# %%
os.listdir(folder_path)
# Out:
# ['Python_Datascience.pdf', 'SQL Lecture 3.pptx']

# %%
# !rm -rf "docs/.ipynb_checkpoints"

# %%
# !sudo apt-get update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://cli.github.com/packages stable/main amd64 Packages [344 B]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,361 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.2 kB]
# ...

# %%
# !sudo apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 40 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.11 [186 kB]
# Fetched 186 kB in 0s (386 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# ...

# %%
# !sudo apt-get install -y libleptonica-dev tesseract-ocr libtesseract-dev python3-pil tesseract-ocr-eng
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# tesseract-ocr-eng is already the newest version (1:4.00~git30-7274cfa-1.1).
# tesseract-ocr-eng set to manually installed.
# The following additional packages will be installed:
#   libarchive-dev libimagequant0 libraqm0 python3-olefile
# Suggested packages:
#   python-pil-doc
# The following NEW packages will be installed:
#   libarchive-dev libimagequant0 libleptonica-dev libraqm0 libtesseract-dev
#   python3-olefile python3-pil
# 0 upgraded, 7 newly installed, 0 to remove and 40 not upgraded.
# Need to get 4,243 kB of archives.
# After this operation, 17.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libarchive-dev amd64 3.6.0-1ubuntu1.5 [581 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libimagequant0 amd64 2.17.0-1 [34.6 kB]
# ...

# %%
# !pip install unstructured-pytesseract
# !pip install tesseract-ocr
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tesseract-ocr: filename=tesseract_ocr-0.0.1-cp312-cp312-linux_x86_64.whl size=188044 sha256=b85b90125c27b68652f9f86df9d01a824ea1554f0f2425b19339c408b0913612
#   Stored in directory: /root/.cache/pip/wheels/c4/96/8d/1e2b502793a5aa288a72ffdc5e96e9ebd22a72be6c0af195b5
# Successfully built tesseract-ocr
# ...

# %%
# !pip install "unstructured[pptx]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 14.9 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain_astradb

# %%
# !pip install langchain langchain-openai datasets pypdf

# %%
from langchain_community.document_loaders import DirectoryLoader

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import UnstructuredPDFLoader

# %%
from langchain_community.document_loaders import DirectoryLoader
loader = DirectoryLoader('./docs')

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=512,
    chunk_overlap=64,
)

# %%
docs = loader.load_and_split(text_splitter=splitter)

# %%
import os
from getpass import getpass

from datasets import load_dataset
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.documents import Document
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import UnstructuredPDFLoader
from langchain.indexes import VectorstoreIndexCreator

# %%
from google.colab import userdata
OPENAI_API_KEY=userdata.get('OPENAI_API_KEY')
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

embedding = OpenAIEmbeddings

# %%
embedding = OpenAIEmbeddings()

# %%
from langchain_astradb import AstraDBVectorStore
from langchain.indexes import VectorstoreIndexCreator

# %%
ASTRA_DB_APPLICATION_TOKEN="AstraCS:JeIFfTWWyIcZLOJTmzZJpMFu:8973ccd3da95cac167dd4e1a847956f51be4fe6715be0a299ce07c9aa50ad986"
ASTRA_DB_API_ENDPOINT="https://7b014487-9501-4fa9-8297-3b4679d61798-us-east1.apps.astra.datastax.com"
ASTRA_DB_KEYSPACE="default_keyspace"

# %%
vstore = AstraDBVectorStore(
    embedding=embedding,
    collection_name="multidoc_vector",
    api_endpoint=ASTRA_DB_API_ENDPOINT,
    token=ASTRA_DB_APPLICATION_TOKEN,
    namespace=ASTRA_DB_KEYSPACE,
)

# %%
inserted_ids = vstore.add_documents(docs)
print(len(inserted_ids))
# Out:
# 2257

# %%
prompt_template = """
You are an expert data science tutor and SQL analyst. Use the provided context from the user's documents (book: "Data Science with Python", and SQL lecture slides) to answer the question accurately and clearly.

Follow these rules:
1. Use only the information retrieved from the context to answer.
2. If the context does not contain enough information, say: "The provided materials do not contain enough details about this topic."
3. When explaining code or queries, give step-by-step reasoning.
4. For Python topics, include short code snippets where relevant.
5. For SQL topics, provide clear examples and explain each clause.

Context:
{context}

Question:
{question}

Your Answer:"""

# %%
prompt_template = ChatPromptTemplate.from_template(prompt_template)

# %%
retriever = vstore.as_retriever(search_kwargs={"k":3})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['AstraDBVectorStore', 'OpenAIEmbeddings'], vectorstore=<langchain_astradb.vectorstores.AstraDBVectorStore object at 0x78b7e78d0710>, search_kwargs={'k': 3})

# %%
llm = ChatOpenAI()

# %%
chain = (
    {
        "context": retriever,
        "question": RunnablePassthrough(),
    }
    | prompt_template
    | llm
    | StrOutputParser()
)

# %%
chain.invoke("Can you tell me how decison tree algorithm works")
# Out:
# 'Decision trees work by iteratively splitting the data along one or the other axis according to some quantitative criterion. At each level, the algorithm assigns the label of the new region based on a majority vote of points within it. The binary splitting method is efficient, cutting the number of options by approximately half with each question asked. In machine learning implementations of decision trees, the questions usually take the form of axis-aligned splits in the data, where each node in the tree divides the data into two groups using a cutoff.'

# %%
chain.invoke("why sky is blue?")
# Out:
# 'The provided materials do not contain enough details about this topic.'

# %%
chain.invoke("How to create a histogram with matplotlib?")
# Out:
# 'To create a histogram with Matplotlib, you can use the plt.hist() function. Here is a step-by-step guide based on the provided context:\n\n1. Make sure you have imported Matplotlib and any other necessary libraries.\n2. Generate or load your data that you want to plot in the histogram.\n3. Use the plt.hist() function to plot the histogram. For example:\n   ```\n   import matplotlib.pyplot as plt\n   import numpy as np\n   \n   data = np.random.randn(1000)  # Example data generation\n   plt.hist(data)\n   ```\n4. Display the histogram using plt.show() or another appropriate method.\n\nFollowing these steps will allow you to create a histogram using Matplotlib in Python.'

# %%
chain.invoke("Briefly describe different kind of joins in")
# Out:
# 'There are four main types of SQL joins:\n1. INNER JOIN: Returns records that have matching values in both tables.\n2. LEFT (OUTER) JOIN: Returns all records from the left table, and the matched records from the right table.\n3. RIGHT (OUTER) JOIN: Returns all records from the right table, and the matched records from the left table.\n4. FULL (OUTER) JOIN: Returns all records when there is a match in either the left or right table.'
